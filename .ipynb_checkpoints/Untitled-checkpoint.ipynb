# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\vostr\Desktop\car2\CarPrice_Assignment.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df1 = df.drop(labels = ['car_ID','doornumber','enginelocation','drivewheel','fuelsystem','peakrpm','highwaympg','aspiration','carlength','carheight','carwidth','cylindernumber','curbweight'],axis = 1)
df1.head(20)
# Out:
#     symboling                   CarName fueltype      carbody  wheelbase  \
# 0           3        alfa-romero giulia      gas  convertible       88.6
# 1           3       alfa-romero stelvio      gas  convertible       88.6
# 2           1  alfa-romero Quadrifoglio      gas    hatchback       94.5
# 3           2               audi 100 ls      gas        sedan       99.8
# 4           2                audi 100ls      gas        sedan       99.4
# 5           2                  audi fox      gas        sedan       99.8
# 6           1                audi 100ls      gas        sedan      105.8
# 7           1                 audi 5000      gas        wagon      105.8
# 8           1                 audi 4000      gas        sedan      105.8
# 9           0       audi 5000s (diesel)      gas    hatchback       99.5
# 10          2                  bmw 320i      gas        sedan      101.2
# 11          0                  bmw 320i      gas        sedan      101.2
# ...

# %%
df1['enginetype'].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf', 'dohcv'], dtype=object)

# %%
df1['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
df1['CarName'] = df1['CarName'].str.split(' ').str.slice(0,4).str.join('')

# %%
df1.head()
# Out:
#    symboling                  CarName fueltype      carbody  wheelbase  \
# 0          3        alfa-romerogiulia      gas  convertible       88.6
# 1          3       alfa-romerostelvio      gas  convertible       88.6
# 2          1  alfa-romeroQuadrifoglio      gas    hatchback       94.5
# 3          2                audi100ls      gas        sedan       99.8
# 4          2                audi100ls      gas        sedan       99.4
#
#   enginetype  enginesize  boreratio  stroke  compressionratio  horsepower  \
# 0       dohc         130       3.47    2.68               9.0         111
# 1       dohc         130       3.47    2.68               9.0         111
# 2       ohcv         152       2.68    3.47               9.0         154
# 3        ohc         109       3.19    3.40              10.0         102
# 4        ohc         136       3.19    3.40               8.0         115
#
#    citympg    price
# 0       21  13495.0
# 1       21  16500.0
# 2       19  16500.0
# ...

# %%
categorical = df1.copy()
categorical.drop(columns = ['symboling','wheelbase','enginesize','boreratio','stroke','compressionratio','horsepower','citympg','price'])
# Out:
#                      CarName fueltype      carbody enginetype
# 0          alfa-romerogiulia      gas  convertible       dohc
# 1         alfa-romerostelvio      gas  convertible       dohc
# 2    alfa-romeroQuadrifoglio      gas    hatchback       ohcv
# 3                  audi100ls      gas        sedan        ohc
# 4                  audi100ls      gas        sedan        ohc
# ..                       ...      ...          ...        ...
# 200            volvo145e(sw)      gas        sedan        ohc
# 201               volvo144ea      gas        sedan        ohc
# 202               volvo244dl      gas        sedan       ohcv
# 203                 volvo246   diesel        sedan        ohc
# 204               volvo264gl      gas        sedan        ohc
#
# [205 rows x 4 columns]

# %%
pd.get_dummies(categorical,drop_first = True).shape
# Out:
# (205, 165)

# %%
X_train,X_test,y_train,y_test
